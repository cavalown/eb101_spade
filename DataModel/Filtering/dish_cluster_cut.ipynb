# %%
import pandas as pd

# %%
df = pd.read_csv('dish_clusters2.csv')
df.head()
# Out:
#    Unnamed: 0      r_id                 recipe  Calories.kcal.  Moisture.g.  \
# 0           1  10000004                 紅心 地瓜包        225.4649      30.6556
# 1           2  10000005                   香蒜餅乾        349.4776      28.1238
# 2           3  10000006         袪濕消腫   薏仁紅豆桂圓茶        343.4000      10.7081
# 3           4  10000007              (煮食影片)檸檬醋        236.2800      38.8182
# 4           5  10000009  [和風四季豆] 娘娘私廚 愛上料理365天        198.2559      49.2696
#
#    Protein.g.  Crude_fat.g.  Saturated_fat.g.  Ash.g.  Carbohydrate.g.  ...  \
# 0      4.2572        2.2301            0.8451  0.6016          46.7204  ...
# 1      6.8457       14.2418            5.8018  2.1056          48.6833  ...
# 2      9.7045        1.7814            0.2499  2.5904          75.2156  ...
# 3      0.2402        0.1810            0.0667  0.1389          60.6216  ...
# 4      2.3973        2.3112            0.4061  2.4441          43.5778  ...
#
# ...

# %%
df1 = df[df.Cluster==1]
df1.head()
df1.to_csv('dishCluster1.csv', index=False)

# %%
df2 = df[df.Cluster==2]
df2.head()
df2.to_csv('dishCluster2.csv', index=False)

# %%
df3 = df[df.Cluster==3]
df3.head()
df3.to_csv('dishCluster3.csv', index=False)

# %%
df4 = df[df.Cluster==4]
df4.head()
df4.to_csv('dishCluster4.csv', index=False)

# %%
df5 = df[df.Cluster==5]
df5.head()
df5.to_csv('dishCluster5.csv', index=False)

# %%
df6 = df[df.Cluster==6]
df6.head()
df6.to_csv('dishCluster6.csv', index=False)

# %%
df7 = df[df.Cluster==7]
df7.head()
df7.to_csv('dishCluster7.csv', index=False)
